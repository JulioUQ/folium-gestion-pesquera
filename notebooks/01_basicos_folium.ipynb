# %% [markdown]
# # **Creación de Mapas Interactivos en Python**
#
# La visualización de datos geográficos es una de las herramientas más poderosas para comunicar información compleja de manera intuitiva. Folium, basada en Leaflet.js, permite crear mapas interactivos fácilmente desde Python, integrando datos, marcadores y capas personalizadas.
#
# Este manual guiará paso a paso para que cualquier persona con conocimientos básicos de Python pueda crear visualizaciones geoespaciales de alto impacto.
#
# ## **Índice**
#
# 1. Introducción a Folium
#    - ¿Qué es Folium?
#    - Instalación y configuración inicial
#    - Primer mapa en 5 líneas de código
#
# 2. Conceptos Fundamentales
#    - Estructura básica de un mapa
#    - Control de ubicación y zoom
#    - Guardado y visualización de mapas
#
# 3. Elementos Básicos en Folium
#    - Marcadores simples
#    - Popups y Tooltips
#    - Iconos personalizados
#
# 4. Capas y Controles
#    - Capas de marcadores
#    - Capas de polígonos y líneas
#    - Control de capas y visibilidad
#
# 5. Integración con Datos
#    - Importar datos desde CSV
#    - Visualización de datos con GeoJSON
#    - Mapas coropléticos
#
# 6. Personalización Avanzada
#    - Colores y estilos dinámicos
#    - Integración con Pandas y Geopandas
#    - Mapas temáticos
#
# 7. Casos Prácticos
#    - Mapa de calor
#    - Mapas con rutas
#    - Dashboard geográfico interactivo
#
# 8. Exportación y Publicación
#    - Guardar en HTML
#    - Integración en aplicaciones web
#    - Compartir en plataformas
#
# 9. Buenas Prácticas y Optimización
#    - Rendimiento en grandes datasets
#    - Accesibilidad y usabilidad
#    - Compatibilidad y mantenimiento
#
# 10. Recursos y Referencias
#     - Documentación oficial
#     - Ejemplos y repositorios
#     - Bibliografía

# %% [markdown]
# ---

# %% [markdown]
# # **Capítulo 1 – Introducción a Folium**
# ## **1.1 ¿Qué es Folium?**
#
# Folium es una librería de Python que actúa como puente hacia la potente biblioteca JavaScript Leaflet.js, permitiendo crear mapas interactivos directamente desde scripts de Python o notebooks Jupyter. Es ideal para visualizaciones geoespaciales que combinan datos con interactividad.
#
# ## **1.2 Instalación y Configuración**
#
# Para instalar Folium:
#
# ```bash
# pip install folium
# ```
#
# Para comprobar la instalacion en Python:

# %%
import folium
print(folium.__version__)
# Out:
# 0.20.0

# %% [markdown]
# ## **1.3 Primer Mapa en 4 Líneas de Código**

# %%
# Crear mapa centrado en coordenadas específicas
mapa = folium.Map(location=[40.4168, -3.7038], 
                  zoom_start=10)

# Mostrar en Jupyter Notebook
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_973e79b2c8aabbb2d46396e8dba934b8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_973e79b2c8aabbb2d46396e8dba934b8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_973e79b2c8aabbb2d46396e8dba934b8 = L.map(
#                 &quot;map_973e79b2c8aabbb2d46396e8dba934b8&quot;,
#                 {
#                     center: [40.4168, -3.7038],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_10406135dc5936b9efc3eae5a816ff42 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_10406135dc5936b9efc3eae5a816ff42.addTo(map_973e79b2c8aabbb2d46396e8dba934b8);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ---

# %% [markdown]
# # **Capítulo 2 – Conceptos Fundamentales**
# ## **2.1 Estructura Básica de un Mapa**
#
# En Folium, un mapa se crea a partir de la clase `folium.Map()` con tres parámetros clave:
#
# | Parámetro    | Descripción                             | Ejemplo                                                     |
# | ------------ | --------------------------------------- | ----------------------------------------------------------- |
# | `location`   | Lista con latitud y longitud iniciales. | `[40.4168, -3.7038]`                                        |
# | `zoom_start` | Nivel inicial de zoom (1–18).           | `zoom_start=12`                                             |
# | `tiles`      | Tipo de mapa base.                      | `"OpenStreetMap"`, `"Stamen Terrain"`, `"CartoDB positron"` |

# %%
mapa = folium.Map(
    location=[40.4168, -3.7038],
    zoom_start=12,
    tiles="CartoDB positron"
)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_062f88cf22f52d42e7fe116d3f2882d6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_062f88cf22f52d42e7fe116d3f2882d6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_062f88cf22f52d42e7fe116d3f2882d6 = L.map(
#                 &quot;map_062f88cf22f52d42e7fe116d3f2882d6&quot;,
#                 {
#                     center: [40.4168, -3.7038],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dfea7a4a10d012948bc1fe770b7b386c = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dfea7a4a10d012948bc1fe770b7b386c.addTo(map_062f88cf22f52d42e7fe116d3f2882d6);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## **2.2 Control de Ubicación y Zoom**
#
# Folium permite mover la vista inicial según nuestras necesidades.

# %%
# Madrid con zoom detallado
mapa_centro = folium.Map(location=[40.4168, -3.7038], zoom_start=14)
mapa_centro
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2f1df28a47a4d592bcd837cef56c37c3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2f1df28a47a4d592bcd837cef56c37c3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2f1df28a47a4d592bcd837cef56c37c3 = L.map(
#                 &quot;map_2f1df28a47a4d592bcd837cef56c37c3&quot;,
#                 {
#                     center: [40.4168, -3.7038],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0e45dfd15b5acc9d2d515457d75690f3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0e45dfd15b5acc9d2d515457d75690f3.addTo(map_2f1df28a47a4d592bcd837cef56c37c3);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Zoom recomendado según tipo de visualización:
#
# | Zoom  | Uso típico                  |
# | ----- | --------------------------- |
# | 2–4   | Vista continental o mundial |
# | 5–8   | Vista regional              |
# | 9–12  | Vista urbana                |
# | 13–16 | Vista de calles             |
# | 17–18 | Detalles de edificios       |

# %% [markdown]
# ## **2.3 Guardado y Visualización**
#
# En Jupyter Notebook, basta con escribir el nombre del objeto para mostrarlo.
# En scripts, se guarda como HTML.

# %%
mapa.save("mapa_madrid.html")

# %% [markdown]
# ---

# %% [markdown]
# # **Capítulo 3 – Elementos Básicos en Folium**
# ## **3.1 Marcadores Simples**
#
# Un marcador indica un punto específico en el mapa.

# %%
m = folium.Map(location=[40.4168, -3.7038], zoom_start=12)

folium.Marker(
    location=[40.4183, -3.7028], 
    popup="Puerta del Sol", 
    tooltip="Click para más info"
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d3cc08701dc6dd957ae4450797486732 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d3cc08701dc6dd957ae4450797486732&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d3cc08701dc6dd957ae4450797486732 = L.map(
#                 &quot;map_d3cc08701dc6dd957ae4450797486732&quot;,
#                 {
#                     center: [40.4168, -3.7038],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5a631369105045a7daed287d39b9e1f1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5a631369105045a7daed287d39b9e1f1.addTo(map_d3cc08701dc6dd957ae4450797486732);
#
#
#             var marker_ecfffd95e194cccc91f98b500c468440 = L.marker(
#                 [40.4183, -3.7028],
#                 {
# }
#             ).addTo(map_d3cc08701dc6dd957ae4450797486732);
#
#
#         var popup_7c456c191750b12328784252640f4103 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2b82f3073e28e0bfd0e7542cd8ff113 = $(`&lt;div id=&quot;html_e2b82f3073e28e0bfd0e7542cd8ff113&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Puerta del Sol&lt;/div&gt;`)[0];
#                 popup_7c456c191750b12328784252640f4103.setContent(html_e2b82f3073e28e0bfd0e7542cd8ff113);
#
#
#
#         marker_ecfffd95e194cccc91f98b500c468440.bindPopup(popup_7c456c191750b12328784252640f4103)
#         ;
#
#
#
#
#             marker_ecfffd95e194cccc91f98b500c468440.bindTooltip(
#                 `&lt;div&gt;
#                      Click para más info
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## **3.2. Popups y Tooltips**
#
# - Popup → texto/HTML que aparece al hacer clic.
# - Tooltip → texto que aparece al pasar el ratón.
#
# **Ejemplo con HTML en popup:**

# %%
folium.Marker(
    location=[40.4183, -3.7028],
    popup=folium.Popup("<b>Puerta del Sol</b><br>Centro de Madrid", max_width=200),
    tooltip="Punto turístico"
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d3cc08701dc6dd957ae4450797486732 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d3cc08701dc6dd957ae4450797486732&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d3cc08701dc6dd957ae4450797486732 = L.map(
#                 &quot;map_d3cc08701dc6dd957ae4450797486732&quot;,
#                 {
#                     center: [40.4168, -3.7038],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5a631369105045a7daed287d39b9e1f1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5a631369105045a7daed287d39b9e1f1.addTo(map_d3cc08701dc6dd957ae4450797486732);
#
#
#             var marker_ecfffd95e194cccc91f98b500c468440 = L.marker(
#                 [40.4183, -3.7028],
#                 {
# }
#             ).addTo(map_d3cc08701dc6dd957ae4450797486732);
#
#
#         var popup_7c456c191750b12328784252640f4103 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2b82f3073e28e0bfd0e7542cd8ff113 = $(`&lt;div id=&quot;html_e2b82f3073e28e0bfd0e7542cd8ff113&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Puerta del Sol&lt;/div&gt;`)[0];
#                 popup_7c456c191750b12328784252640f4103.setContent(html_e2b82f3073e28e0bfd0e7542cd8ff113);
#
#
#
#         marker_ecfffd95e194cccc91f98b500c468440.bindPopup(popup_7c456c191750b12328784252640f4103)
#         ;
#
#
#
#
#             marker_ecfffd95e194cccc91f98b500c468440.bindTooltip(
#                 `&lt;div&gt;
#                      Click para más info
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             tile_layer_5a631369105045a7daed287d39b9e1f1.addTo(map_d3cc08701dc6dd957ae4450797486732);
#
#
#             var marker_d967b5798be4b610ab8c385e97e88038 = L.marker(
#                 [40.4183, -3.7028],
#                 {
# }
#             ).addTo(map_d3cc08701dc6dd957ae4450797486732);
#
#
#         var popup_d1b5a12553d022f3664275f975f42fb2 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_33059637a40ecd918e2fd26dc397757a = $(`&lt;div id=&quot;html_33059637a40ecd918e2fd26dc397757a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Puerta del Sol&lt;/b&gt;&lt;br&gt;Centro de Madrid&lt;/div&gt;`)[0];
#                 popup_d1b5a12553d022f3664275f975f42fb2.setContent(html_33059637a40ecd918e2fd26dc397757a);
#
#
#
#         marker_d967b5798be4b610ab8c385e97e88038.bindPopup(popup_d1b5a12553d022f3664275f975f42fb2)
#         ;
#
#
#
#
#             marker_d967b5798be4b610ab8c385e97e88038.bindTooltip(
#                 `&lt;div&gt;
#                      Punto turístico
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## **3.3 Iconos Personalizados**

# %%
folium.Marker(
    location=[40.417, -3.703],
    popup="Icono verde",
    icon=folium.Icon(color="green", icon="info-sign")
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d3cc08701dc6dd957ae4450797486732 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d3cc08701dc6dd957ae4450797486732&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d3cc08701dc6dd957ae4450797486732 = L.map(
#                 &quot;map_d3cc08701dc6dd957ae4450797486732&quot;,
#                 {
#                     center: [40.4168, -3.7038],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5a631369105045a7daed287d39b9e1f1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5a631369105045a7daed287d39b9e1f1.addTo(map_d3cc08701dc6dd957ae4450797486732);
#
#
#             var marker_ecfffd95e194cccc91f98b500c468440 = L.marker(
#                 [40.4183, -3.7028],
#                 {
# }
#             ).addTo(map_d3cc08701dc6dd957ae4450797486732);
#
#
#         var popup_7c456c191750b12328784252640f4103 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2b82f3073e28e0bfd0e7542cd8ff113 = $(`&lt;div id=&quot;html_e2b82f3073e28e0bfd0e7542cd8ff113&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Puerta del Sol&lt;/div&gt;`)[0];
#                 popup_7c456c191750b12328784252640f4103.setContent(html_e2b82f3073e28e0bfd0e7542cd8ff113);
#
#
#
#         marker_ecfffd95e194cccc91f98b500c468440.bindPopup(popup_7c456c191750b12328784252640f4103)
#         ;
#
#
#
#
#             marker_ecfffd95e194cccc91f98b500c468440.bindTooltip(
#                 `&lt;div&gt;
#                      Click para más info
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             tile_layer_5a631369105045a7daed287d39b9e1f1.addTo(map_d3cc08701dc6dd957ae4450797486732);
#
#
#             var marker_d967b5798be4b610ab8c385e97e88038 = L.marker(
#                 [40.4183, -3.7028],
#                 {
# }
#             ).addTo(map_d3cc08701dc6dd957ae4450797486732);
#
#
#         var popup_d1b5a12553d022f3664275f975f42fb2 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_33059637a40ecd918e2fd26dc397757a = $(`&lt;div id=&quot;html_33059637a40ecd918e2fd26dc397757a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Puerta del Sol&lt;/b&gt;&lt;br&gt;Centro de Madrid&lt;/div&gt;`)[0];
#                 popup_d1b5a12553d022f3664275f975f42fb2.setContent(html_33059637a40ecd918e2fd26dc397757a);
#
#
#
#         marker_d967b5798be4b610ab8c385e97e88038.bindPopup(popup_d1b5a12553d022f3664275f975f42fb2)
#         ;
#
#
#
#
#             marker_d967b5798be4b610ab8c385e97e88038.bindTooltip(
#                 `&lt;div&gt;
#                      Punto turístico
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             tile_layer_5a631369105045a7daed287d39b9e1f1.addTo(map_d3cc08701dc6dd957ae4450797486732);
#
#
#             var marker_7b63e83c0b2e1d6638668f20c6a9fa1c = L.marker(
#                 [40.417, -3.703],
#                 {
# }
#             ).addTo(map_d3cc08701dc6dd957ae4450797486732);
#
#
#             var icon_27040fc087ac3af103a7ebffbe6f3cc2 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4538ecf153778432b320940131f29969 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_600d65ed4ce4bf40b4658f26666ea6cc = $(`&lt;div id=&quot;html_600d65ed4ce4bf40b4658f26666ea6cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Icono verde&lt;/div&gt;`)[0];
#                 popup_4538ecf153778432b320940131f29969.setContent(html_600d65ed4ce4bf40b4658f26666ea6cc);
#
#
#
#         marker_7b63e83c0b2e1d6638668f20c6a9fa1c.bindPopup(popup_4538ecf153778432b320940131f29969)
#         ;
#
#
#
#
#                 marker_7b63e83c0b2e1d6638668f20c6a9fa1c.setIcon(icon_27040fc087ac3af103a7ebffbe6f3cc2);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **Colores disponibles:**
# > ["red", "blue", "green", "purple", "orange", "darkred", "lightred", "beige", "darkblue", "darkgreen", "cadetblue", "darkpurple", "white", "pink", "lightblue", "lightgreen", "gray", "black", "lightgray"]

# %% [markdown]
# ## **Compartiva entre marcadores**
#
# | Elemento        | Descripción            | Ejemplo                              |
# | --------------- | ---------------------- | ------------------------------------ |
# | `folium.Marker` | Punto único en el mapa | `folium.Marker(location=[lat, lon])` |
# | `popup`         | Texto al clic          | `popup="Texto"`                      |
# | `tooltip`       | Texto al pasar ratón   | `tooltip="Texto"`                    |
# | `icon`          | Icono y color          | `folium.Icon(color="blue")`          |

# %% [markdown]
# ---

# %% [markdown]
# # **Capítulo 4 – Capas y Controles**
# En Folium, las capas son elementos que podemos superponer o alternar en un mapa. Esto incluye marcadores, líneas, polígonos, imágenes y datos geoespaciales.
#
# ## **4.1 Capas de Marcadores**
# Ejemplo:

# %%
m = folium.Map(location=[40.4168, -3.7038], zoom_start=12, tiles="CartoDB positron")

# Grupo de marcadores
marker_layer = folium.FeatureGroup(name="Puntos de interés")

marker_layer.add_child(
    folium.Marker([40.4183, -3.7028], popup="Puerta del Sol", tooltip="Centro de Madrid")
)
marker_layer.add_child(
    folium.Marker([40.4138, -3.6922], popup="Parque del Retiro", tooltip="Área verde")
)

m.add_child(marker_layer)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4b0ac0c55ce3c46a198033855c861c16 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4b0ac0c55ce3c46a198033855c861c16&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4b0ac0c55ce3c46a198033855c861c16 = L.map(
#                 &quot;map_4b0ac0c55ce3c46a198033855c861c16&quot;,
#                 {
#                     center: [40.4168, -3.7038],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dbc398d25de2891c8cd29eadbe05e2f3 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dbc398d25de2891c8cd29eadbe05e2f3.addTo(map_4b0ac0c55ce3c46a198033855c861c16);
#
#
#             var feature_group_102847f6c1831639d88ebd4b043b6421 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_cc17486dcf75a3c6fb28a355bfb64fb1 = L.marker(
#                 [40.4183, -3.7028],
#                 {
# }
#             ).addTo(feature_group_102847f6c1831639d88ebd4b043b6421);
#
#
#         var popup_b8d618490d83af7defd9e3bf27a80134 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06a8e5b6ab42438773ab12dbc2b68761 = $(`&lt;div id=&quot;html_06a8e5b6ab42438773ab12dbc2b68761&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Puerta del Sol&lt;/div&gt;`)[0];
#                 popup_b8d618490d83af7defd9e3bf27a80134.setContent(html_06a8e5b6ab42438773ab12dbc2b68761);
#
#
#
#         marker_cc17486dcf75a3c6fb28a355bfb64fb1.bindPopup(popup_b8d618490d83af7defd9e3bf27a80134)
#         ;
#
#
#
#
#             marker_cc17486dcf75a3c6fb28a355bfb64fb1.bindTooltip(
#                 `&lt;div&gt;
#                      Centro de Madrid
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_ab5d5986bf495a90bbee6dd140350577 = L.marker(
#                 [40.4138, -3.6922],
#                 {
# }
#             ).addTo(feature_group_102847f6c1831639d88ebd4b043b6421);
#
#
#         var popup_9f2015cf0d05b82bf4479c65d2e3c862 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_afbee069d19d8c368e967e8cc3168cae = $(`&lt;div id=&quot;html_afbee069d19d8c368e967e8cc3168cae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Parque del Retiro&lt;/div&gt;`)[0];
#                 popup_9f2015cf0d05b82bf4479c65d2e3c862.setContent(html_afbee069d19d8c368e967e8cc3168cae);
#
#
#
#         marker_ab5d5986bf495a90bbee6dd140350577.bindPopup(popup_9f2015cf0d05b82bf4479c65d2e3c862)
#         ;
#
#
#
#
#             marker_ab5d5986bf495a90bbee6dd140350577.bindTooltip(
#                 `&lt;div&gt;
#                      Área verde
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             feature_group_102847f6c1831639d88ebd4b043b6421.addTo(map_4b0ac0c55ce3c46a198033855c861c16);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## **4.2 Capas de Líneas**
# Las líneas se crean con `folium.PolyLine`.

# %%
marker_layer.add_child(
    folium.Marker([40.4154, -3.7074], popup="Plaza Mayor", tooltip="Plaza")
)

m.add_child(marker_layer)

ruta = folium.FeatureGroup(name="Ruta turística")

ruta.add_child(
    folium.PolyLine(
        locations=[
            [40.4183, -3.7028],  # Puerta del Sol
            [40.4154, -3.7074],  # Plaza Mayor
            [40.4138, -3.6922]   # Retiro
        ],
        color="blue",
        weight=4,
        opacity=0.7
    )
)

m.add_child(ruta)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4b0ac0c55ce3c46a198033855c861c16 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4b0ac0c55ce3c46a198033855c861c16&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4b0ac0c55ce3c46a198033855c861c16 = L.map(
#                 &quot;map_4b0ac0c55ce3c46a198033855c861c16&quot;,
#                 {
#                     center: [40.4168, -3.7038],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dbc398d25de2891c8cd29eadbe05e2f3 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dbc398d25de2891c8cd29eadbe05e2f3.addTo(map_4b0ac0c55ce3c46a198033855c861c16);
#
#
#             var feature_group_102847f6c1831639d88ebd4b043b6421 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_cc17486dcf75a3c6fb28a355bfb64fb1 = L.marker(
#                 [40.4183, -3.7028],
#                 {
# }
#             ).addTo(feature_group_102847f6c1831639d88ebd4b043b6421);
#
#
#         var popup_b8d618490d83af7defd9e3bf27a80134 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06a8e5b6ab42438773ab12dbc2b68761 = $(`&lt;div id=&quot;html_06a8e5b6ab42438773ab12dbc2b68761&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Puerta del Sol&lt;/div&gt;`)[0];
#                 popup_b8d618490d83af7defd9e3bf27a80134.setContent(html_06a8e5b6ab42438773ab12dbc2b68761);
#
#
#
#         marker_cc17486dcf75a3c6fb28a355bfb64fb1.bindPopup(popup_b8d618490d83af7defd9e3bf27a80134)
#         ;
#
#
#
#
#             marker_cc17486dcf75a3c6fb28a355bfb64fb1.bindTooltip(
#                 `&lt;div&gt;
#                      Centro de Madrid
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_ab5d5986bf495a90bbee6dd140350577 = L.marker(
#                 [40.4138, -3.6922],
#                 {
# }
#             ).addTo(feature_group_102847f6c1831639d88ebd4b043b6421);
#
#
#         var popup_9f2015cf0d05b82bf4479c65d2e3c862 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_afbee069d19d8c368e967e8cc3168cae = $(`&lt;div id=&quot;html_afbee069d19d8c368e967e8cc3168cae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Parque del Retiro&lt;/div&gt;`)[0];
#                 popup_9f2015cf0d05b82bf4479c65d2e3c862.setContent(html_afbee069d19d8c368e967e8cc3168cae);
#
#
#
#         marker_ab5d5986bf495a90bbee6dd140350577.bindPopup(popup_9f2015cf0d05b82bf4479c65d2e3c862)
#         ;
#
#
#
#
#             marker_ab5d5986bf495a90bbee6dd140350577.bindTooltip(
#                 `&lt;div&gt;
#                      Área verde
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             feature_group_102847f6c1831639d88ebd4b043b6421.addTo(map_4b0ac0c55ce3c46a198033855c861c16);
#
#
#             tile_layer_dbc398d25de2891c8cd29eadbe05e2f3.addTo(map_4b0ac0c55ce3c46a198033855c861c16);
#
#
#             feature_group_102847f6c1831639d88ebd4b043b6421.addTo(map_4b0ac0c55ce3c46a198033855c861c16);
#
#
#             var feature_group_d59c8b7ba2e3d019b498cec0a439f81c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var poly_line_41cd302c1a9dbc357032b0de002efda1 = L.polyline(
#                 [[40.4183, -3.7028], [40.4154, -3.7074], [40.4138, -3.6922]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.7, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 4}
#             ).addTo(feature_group_d59c8b7ba2e3d019b498cec0a439f81c);
#
#
#             feature_group_d59c8b7ba2e3d019b498cec0a439f81c.addTo(map_4b0ac0c55ce3c46a198033855c861c16);
#
#
#             tile_layer_dbc398d25de2891c8cd29eadbe05e2f3.addTo(map_4b0ac0c55ce3c46a198033855c861c16);
#
#
#             feature_group_102847f6c1831639d88ebd4b043b6421.addTo(map_4b0ac0c55ce3c46a198033855c861

# %% [markdown]
# ## **4.3 Capas de Polígonos**

# %%
poligono = folium.FeatureGroup(name="Área destacada")

poligono.add_child(
    folium.Polygon(
        locations=[
            [40.42, -3.71],
            [40.42, -3.69],
            [40.40, -3.69],
            [40.40, -3.71]
        ],
        color="green",
        fill=True,
        fill_opacity=0.4,
        tooltip="Zona delimitada"
    )
)

m.add_child(poligono)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4b0ac0c55ce3c46a198033855c861c16 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4b0ac0c55ce3c46a198033855c861c16&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4b0ac0c55ce3c46a198033855c861c16 = L.map(
#                 &quot;map_4b0ac0c55ce3c46a198033855c861c16&quot;,
#                 {
#                     center: [40.4168, -3.7038],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dbc398d25de2891c8cd29eadbe05e2f3 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dbc398d25de2891c8cd29eadbe05e2f3.addTo(map_4b0ac0c55ce3c46a198033855c861c16);
#
#
#             var feature_group_102847f6c1831639d88ebd4b043b6421 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_cc17486dcf75a3c6fb28a355bfb64fb1 = L.marker(
#                 [40.4183, -3.7028],
#                 {
# }
#             ).addTo(feature_group_102847f6c1831639d88ebd4b043b6421);
#
#
#         var popup_b8d618490d83af7defd9e3bf27a80134 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06a8e5b6ab42438773ab12dbc2b68761 = $(`&lt;div id=&quot;html_06a8e5b6ab42438773ab12dbc2b68761&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Puerta del Sol&lt;/div&gt;`)[0];
#                 popup_b8d618490d83af7defd9e3bf27a80134.setContent(html_06a8e5b6ab42438773ab12dbc2b68761);
#
#
#
#         marker_cc17486dcf75a3c6fb28a355bfb64fb1.bindPopup(popup_b8d618490d83af7defd9e3bf27a80134)
#         ;
#
#
#
#
#             marker_cc17486dcf75a3c6fb28a355bfb64fb1.bindTooltip(
#                 `&lt;div&gt;
#                      Centro de Madrid
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_ab5d5986bf495a90bbee6dd140350577 = L.marker(
#                 [40.4138, -3.6922],
#                 {
# }
#             ).addTo(feature_group_102847f6c1831639d88ebd4b043b6421);
#
#
#         var popup_9f2015cf0d05b82bf4479c65d2e3c862 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_afbee069d19d8c368e967e8cc3168cae = $(`&lt;div id=&quot;html_afbee069d19d8c368e967e8cc3168cae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Parque del Retiro&lt;/div&gt;`)[0];
#                 popup_9f2015cf0d05b82bf4479c65d2e3c862.setContent(html_afbee069d19d8c368e967e8cc3168cae);
#
#
#
#         marker_ab5d5986bf495a90bbee6dd140350577.bindPopup(popup_9f2015cf0d05b82bf4479c65d2e3c862)
#         ;
#
#
#
#
#             marker_ab5d5986bf495a90bbee6dd140350577.bindTooltip(
#                 `&lt;div&gt;
#                      Área verde
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             feature_group_102847f6c1831639d88ebd4b043b6421.addTo(map_4b0ac0c55ce3c46a198033855c861c16);
#
#
#             tile_layer_dbc398d25de2891c8cd29eadbe05e2f3.addTo(map_4b0ac0c55ce3c46a198033855c861c16);
#
#
#             feature_group_102847f6c1831639d88ebd4b043b6421.addTo(map_4b0ac0c55ce3c46a198033855c861c16);
#
#
#             var feature_group_d59c8b7ba2e3d019b498cec0a439f81c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var poly_line_41cd302c1a9dbc357032b0de002efda1 = L.polyline(
#                 [[40.4183, -3.7028], [40.4154, -3.7074], [40.4138, -3.6922]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.7, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 4}
#             ).addTo(feature_group_d59c8b7ba2e3d019b498cec0a439f81c);
#
#
#             feature_group_d59c8b7ba2e3d019b498cec0a439f81c.addTo(map_4b0ac0c55ce3c46a198033855c861c16);
#
#
#             tile_layer_dbc398d25de2891c8cd29eadbe05e2f3.addTo(map_4b0ac0c55ce3c46a198033855c861c16);
#
#
#             feature_group_102847f6c1831639d88ebd4b043b6421.addTo(map_4b0ac0c55ce3c46a198033855c861

# %% [markdown]
# ## **4.4 Control de Capas**
# Para alternar entre capas activas y ocultas:

# %%
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4b0ac0c55ce3c46a198033855c861c16 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4b0ac0c55ce3c46a198033855c861c16&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4b0ac0c55ce3c46a198033855c861c16 = L.map(
#                 &quot;map_4b0ac0c55ce3c46a198033855c861c16&quot;,
#                 {
#                     center: [40.4168, -3.7038],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dbc398d25de2891c8cd29eadbe05e2f3 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dbc398d25de2891c8cd29eadbe05e2f3.addTo(map_4b0ac0c55ce3c46a198033855c861c16);
#
#
#             var feature_group_102847f6c1831639d88ebd4b043b6421 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_cc17486dcf75a3c6fb28a355bfb64fb1 = L.marker(
#                 [40.4183, -3.7028],
#                 {
# }
#             ).addTo(feature_group_102847f6c1831639d88ebd4b043b6421);
#
#
#         var popup_b8d618490d83af7defd9e3bf27a80134 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06a8e5b6ab42438773ab12dbc2b68761 = $(`&lt;div id=&quot;html_06a8e5b6ab42438773ab12dbc2b68761&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Puerta del Sol&lt;/div&gt;`)[0];
#                 popup_b8d618490d83af7defd9e3bf27a80134.setContent(html_06a8e5b6ab42438773ab12dbc2b68761);
#
#
#
#         marker_cc17486dcf75a3c6fb28a355bfb64fb1.bindPopup(popup_b8d618490d83af7defd9e3bf27a80134)
#         ;
#
#
#
#
#             marker_cc17486dcf75a3c6fb28a355bfb64fb1.bindTooltip(
#                 `&lt;div&gt;
#                      Centro de Madrid
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_ab5d5986bf495a90bbee6dd140350577 = L.marker(
#                 [40.4138, -3.6922],
#                 {
# }
#             ).addTo(feature_group_102847f6c1831639d88ebd4b043b6421);
#
#
#         var popup_9f2015cf0d05b82bf4479c65d2e3c862 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_afbee069d19d8c368e967e8cc3168cae = $(`&lt;div id=&quot;html_afbee069d19d8c368e967e8cc3168cae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Parque del Retiro&lt;/div&gt;`)[0];
#                 popup_9f2015cf0d05b82bf4479c65d2e3c862.setContent(html_afbee069d19d8c368e967e8cc3168cae);
#
#
#
#         marker_ab5d5986bf495a90bbee6dd140350577.bindPopup(popup_9f2015cf0d05b82bf4479c65d2e3c862)
#         ;
#
#
#
#
#             marker_ab5d5986bf495a90bbee6dd140350577.bindTooltip(
#                 `&lt;div&gt;
#                      Área verde
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             feature_group_102847f6c1831639d88ebd4b043b6421.addTo(map_4b0ac0c55ce3c46a198033855c861c16);
#
#
#             tile_layer_dbc398d25de2891c8cd29eadbe05e2f3.addTo(map_4b0ac0c55ce3c46a198033855c861c16);
#
#
#             feature_group_102847f6c1831639d88ebd4b043b6421.addTo(map_4b0ac0c55ce3c46a198033855c861c16);
#
#
#             var feature_group_d59c8b7ba2e3d019b498cec0a439f81c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var poly_line_41cd302c1a9dbc357032b0de002efda1 = L.polyline(
#                 [[40.4183, -3.7028], [40.4154, -3.7074], [40.4138, -3.6922]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.7, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 4}
#             ).addTo(feature_group_d59c8b7ba2e3d019b498cec0a439f81c);
#
#
#             feature_group_d59c8b7ba2e3d019b498cec0a439f81c.addTo(map_4b0ac0c55ce3c46a198033855c861c16);
#
#
#             tile_layer_dbc398d25de2891c8cd29eadbe05e2f3.addTo(map_4b0ac0c55ce3c46a198033855c861c16);
#
#
#             feature_group_102847f6c1831639d88ebd4b043b6421.addTo(map_4b0ac0c55ce3c46a198033855c861

# %% [markdown]
# Esto añade un menú interactivo en la esquina superior derecha.

# %% [markdown]
# ## **4.5 Ejemplo Completo – Mapa con Capas Interactivas**

# %%
m = folium.Map(location=[40.4168, -3.7038], zoom_start=13, tiles="CartoDB positron")

# Marcadores
marker_layer = folium.FeatureGroup(name="Puntos turísticos")
marker_layer.add_child(folium.Marker([40.4183, -3.7028], popup="Puerta del Sol"))
marker_layer.add_child(folium.Marker([40.4138, -3.6922], popup="Parque del Retiro"))
m.add_child(marker_layer)

# Línea
ruta = folium.FeatureGroup(name="Ruta")
ruta.add_child(folium.PolyLine([[40.4183, -3.7028], [40.4138, -3.6922]], color="blue"))
m.add_child(ruta)

# Polígono
poligono = folium.FeatureGroup(name="Zona")
poligono.add_child(folium.Polygon(
    [[40.42, -3.71], [40.42, -3.69], [40.40, -3.69], [40.40, -3.71]],
    color="green", fill=True, fill_opacity=0.4
))
m.add_child(poligono)

# Control
folium.LayerControl().add_to(m)

m.save("capas_interactivas.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_507921b6deb4ef6bd97e9760a16b1630 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_507921b6deb4ef6bd97e9760a16b1630&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_507921b6deb4ef6bd97e9760a16b1630 = L.map(
#                 &quot;map_507921b6deb4ef6bd97e9760a16b1630&quot;,
#                 {
#                     center: [40.4168, -3.7038],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c11e021bd4b98c5b52a5ffe3d889da25 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c11e021bd4b98c5b52a5ffe3d889da25.addTo(map_507921b6deb4ef6bd97e9760a16b1630);
#
#
#             var feature_group_27052c8023f3dc0b2bff7ba8cf1889b3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f80581b8d3855a19560b4697529a7588 = L.marker(
#                 [40.4183, -3.7028],
#                 {
# }
#             ).addTo(feature_group_27052c8023f3dc0b2bff7ba8cf1889b3);
#
#
#         var popup_5ddcbb1bceda6542dcbcfdfe900ff18d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f456e47904d290b30a7c1c1e39cc62c = $(`&lt;div id=&quot;html_7f456e47904d290b30a7c1c1e39cc62c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Puerta del Sol&lt;/div&gt;`)[0];
#                 popup_5ddcbb1bceda6542dcbcfdfe900ff18d.setContent(html_7f456e47904d290b30a7c1c1e39cc62c);
#
#
#
#         marker_f80581b8d3855a19560b4697529a7588.bindPopup(popup_5ddcbb1bceda6542dcbcfdfe900ff18d)
#         ;
#
#
#
#
#             var marker_f4541a6517594e87c46825d3ef846d6b = L.marker(
#                 [40.4138, -3.6922],
#                 {
# }
#             ).addTo(feature_group_27052c8023f3dc0b2bff7ba8cf1889b3);
#
#
#         var popup_077587d959c6cec4c16a0ed736ebb5f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d13ec616e7c5a00186c9def949798f8 = $(`&lt;div id=&quot;html_3d13ec616e7c5a00186c9def949798f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Parque del Retiro&lt;/div&gt;`)[0];
#                 popup_077587d959c6cec4c16a0ed736ebb5f3.setContent(html_3d13ec616e7c5a00186c9def949798f8);
#
#
#
#         marker_f4541a6517594e87c46825d3ef846d6b.bindPopup(popup_077587d959c6cec4c16a0ed736ebb5f3)
#         ;
#
#
#
#
#             feature_group_27052c8023f3dc0b2bff7ba8cf1889b3.addTo(map_507921b6deb4ef6bd97e9760a16b1630);
#
#
#             var feature_group_68b102e00ec059c70e83e7641d9b0a2c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var poly_line_29fa254b7d9907923b358e6f61a9aad4 = L.polyline(
#                 [[40.4183, -3.7028], [40.4138, -3.6922]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_68b102e00ec059c70e83e7641d9b0a2c);
#
#
#             feature_group_68b102e00ec059c70e83e7641d9b0a2c.addTo(map_507921b6deb4ef6bd97e9760a16b1630);
#
#
#             var feature_group_97b38278b94e292b94984cb8387d22f6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var polygon_a16be5895606891a7676b76ad3832cc0 = L.polygon(
#                 [[40.42, -3.71], [40.42, -3.69], [40.4, -3.69], [40.4, -3.71]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_97b38278b94e292b94984cb8387d22f6);
#
#
#             feature_group_97b38278b94e292b94984cb8387d22f6.addTo(map_5079

# %% [markdown]
# ---

# %% [markdown]
# # **7. Casos prácticos**
#
# ## **7.1. Crea y guarda tu primer mapa con folium**
#
# - Crea un mapa centrado en Buenos Aires con un zoom de 10.
# - Prueba con tres estilos (tiles) distintos y guarda cada versión en HTML.
#
# ## **7.2. Puntos de interés en ciudades de tu país**
#
# - Crea un mapa con 3 marcadores en diferentes ciudades de tu país.
# - A cada uno añádele un tooltip y un popup con HTML.
# - Guarda el mapa en HTML.
#
# ## **7.3 Añadiendo dimensiones al mapa**
# 1. Crea un mapa con tres capas:
#   - Una capa de marcadores con al menos 3 puntos.
#   - Una capa de polilínea que conecte esos puntos.
#   - Una capa de polígono que cubra la zona.
# 2. Añade LayerControl() para poder alternar las capas.
# 3. Guarda el resultado en un archivo mapa_capas.html.

# %% [markdown]
# # **¿Cuando usar add_child() o add_to()?**
#
# La diferencia entre `add_child()` y `add_to()` en Folium es más de **estilo y orden de escritura** que de funcionalidad, pero hay matices que merece la pena entender.
#
#
# ## 1️⃣ **add\_child()**
#
# * **Forma clásica** usada internamente en Folium.
# * Llamas al método **sobre el mapa o sobre otro objeto contenedor** y le pasas el elemento que quieres añadir como argumento.
# * **Orden:**
#
#   1. Creas el elemento.
#   2. Lo pasas a `add_child()` del mapa (o capa padre).
#
# **Ejemplo:**
#
# ```python
# m = folium.Map(location=[40.4168, -3.7038], zoom_start=13)
#
# marker = folium.Marker(location=[40.4183, -3.7028], popup="Puerta del Sol")
# m.add_child(marker)  # Añadido al mapa
# ```
#
# ---
#
# ## 2️⃣ **add\_to()**
#
# * **Forma encadenada** más moderna y habitual en ejemplos recientes.
# * Llamas al método **sobre el elemento** y le pasas el mapa o capa donde quieres añadirlo.
# * Permite escribir código más compacto.
# * Útil para **encadenar varias operaciones** de forma fluida.
#
# **Ejemplo:**
#
# ```python
# m = folium.Map(location=[40.4168, -3.7038], zoom_start=13)
#
# folium.Marker(location=[40.4183, -3.7028], popup="Puerta del Sol").add_to(m)
# ```
#
# ---
#
# ## 3️⃣ Comparativa
#
# | Aspecto                   | `add_child()`                     | `add_to()`                       |
# | ------------------------- | --------------------------------- | -------------------------------- |
# | **Punto de llamada**      | En el mapa o contenedor           | En el elemento                   |
# | **Estilo**                | Más explícito (padre → hijo)      | Más fluido (hijo → padre)        |
# | **Encadenamiento**        | Menos práctico                    | Permite encadenar                |
# | **Uso interno en Folium** | Muy común                         | Más para usuarios                |
# | **Legibilidad**           | Mejor si hay jerarquías complejas | Mejor para código rápido y claro |
#
# ---
#
# 💡 **Regla práctica**:
#
# * Si estás construyendo **objetos por separado** y luego quieres añadirlos, `add_child()` es más claro.
# * Si creas y añades **en la misma línea**, `add_to()` es más limpio.
#
# ---
#
# Si quieres, puedo incluir en el manual un **apartado de buenas prácticas de codificación con Folium**, donde explique cosas como esta para que quien lo lea sepa cuándo usar cada método.
# ¿Quieres que lo meta como anexo de estilo de código?
